# %%
"""
Дан массив нулей и единиц (общий случай)
[1 1 1 1 0 1 1 0 0 1 1 1 0]

Необходимо найти максимальное число непрерывно идущих единиц, при 
ОБЯЗАТЕЛЬНОМ удалении одного элемента из массива.
(!) Необходимо найти за один проход

Алгоритм:
Инициализация:
- curr_ones
- pred_ones
- max_ones
- zeros

1. Проверяем текущий элемент, если это 1. то добавляем его в curr_sum
2. Если доходим до нуля, то нам нужно убедиться один ли он
 - Если ноль 1, то мы pred_ones = curr_ones, а curr_ones = 0
 (!) В pred_ones мы храним единицы до 1го нуля, чтобы просуммировать потом
 - Если 0 > 1, то pred_ones = 0 и дальше уже будет считаться только curr_ones
 (!) max_ones = 
 
(!) Можем ли смотреть на +1 и +2 индекса вперёд ? Чтобы без счётчика ? -> думаю лишнее усложнение
 
Краевые случаи:
[1 1] - все единицы
[] - пустой
"""

# %%
def get_max_len(nums):

    """
    [0 1 1 1 0 1 1 0 0 1 1 1 0]
    """

    curr_ones = 0
    pred_ones = 0
    max_ones = 0
    zeros = 0

    for num in nums:
        if not pred_ones and num == 1:
            curr_ones += 1

        if num == 1 and zeros == 0:
            curr_ones += 1
        elif num == 1 and zeros == 1:
            pred_ones = curr_ones
        elif num == 0:
            zeros += 1

# %%
pred_ones = 0
if pred_ones:
    print(True)
else:
    print(False)
# Out:
# False
